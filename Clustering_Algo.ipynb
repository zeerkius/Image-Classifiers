# %%
import os
import cv2
import numpy as nd
import matplotlib.pyplot as plt

def cosine(a,b):
    if len(a) != len(b):
        raise ValueError("Vectors must be same size")
    import math
    transform = 0
    index = 0
    unitA = 0
    unitB = 0
    while a and b:
        transform += a[index]*b[index]
        unitA += a[index] * a[index]
        unitB += b[index] * b[index]
        index += 1
        if index == len(a) or len(b):
            break
    unitA = math.sqrt(unitA)
    unitB = math.sqrt(unitB)
    try:
        res = transform / unitA * unitB
    except:
        raise ZeroDivisionError("Cant divide by zero")
    return res

# we will use a threshold after studying our data to see how we can divide our data


def cosine_clustering(Data,k = 2):
    if k > 100:
        raise ValueError("Cluster limit reached")
    steps = 2 / k
    start = -1
    borders = []
    borders.append(-1)
    while start < 1.00:
        start += steps
        borders.append(start)
    # this gives us the 
    

print(cosine_clustering([],k=10))
    
    


print(cosine([1,2,3],[0.5,1.5,2.5]))
        
    

topfile = r"C:\Users\agboo\Downloads\Clustering Data\test_set"

classes = ["dogs" , "cats"]

start = 0

stop = 2

Images = []
h = []
for k in classes:
    path = os.path.join(topfile,k)
    for img in os.listdir(path):
        true_path = os.path.join(path,img)
        new_img = cv2.imread(true_path,cv2.IMREAD_IGNORE_ORIENTATION )
        new_img = cv2.resize(new_img,(75,75))
        plt.imshow(new_img,cmap = "viridis")
        plt.show()
        print(new_img.shape)
        for val in new_img:
            print(val)
        break
    break

l = nd.array([[2,2],[2,2]])
print(l.shape)
class Cluster():
    def __init__(self,data):
        self.data = []
# Out:
# [-1, -0.8, -0.6000000000000001, -0.4000000000000001, -0.20000000000000007, -5.551115123125783e-17, 0.19999999999999996, 0.39999999999999997, 0.6, 0.8, 1.0]
# 0.25
# (75, 75)
# [ 62  13  97  63  70  87  65  10  16  12  13  11   8   7   7   6  10  18
#   34  31   5   2   7   6  61 109  37  60  60  56  80 108 101 167 157 157
#  156 160 158 161 163 164 164 164 167 167 169 165 165 165 165 165 165 162
#  168 164 163 164 164 162 160 158 156 154 152 151 151 151 149 147 144 134
#  138 151 143]
# [118 128 172 164 145 132 104  11  19  12  14  11  11   7   8   4  46 124
#  128 101   5  38   2  10  71 102  34  62  73  72  87 111  59 167 159 156
#  156 159 159 162 164 166 166 166 171 167 166 169 169 168 171 168 166 163
#  166 168 166 166 166 164 160 158 154 153 151 150 150 149 146 144 147 134
#  142 154 146]
# [115 101  77  69  56  52  40  13  21   9  12  14  12  13   8   4 109 132
#  128 108   9  46  14  37  80  78  44  67  68  85  96 115  78 167 142 156
# ...
